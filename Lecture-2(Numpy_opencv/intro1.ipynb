# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
#pil=Image.open("RGB.png")
pil=Image.open("Thor.jpg")

# %%
arr=np.array(pil)

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
red=arr[100:200, : ,2]

# %%
plt.imshow(red)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x225AB5BE8D0>

# %%
cut= arr[:5,:5]

# %%
plt.imshow(cut)

# %%
work =arr.copy()

# %%
work [:,:,[1,2]]=0

# %%
plt.imshow(work)

# %%
gray=arr.mean(axis=2)

# %%
plt.imshow(gray,cmap="gray")  #cmap is used to change color map
